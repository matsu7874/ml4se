# %%
run 02-square_error.py
# Out:
# Table of the coefficients
#        M=0       M=1        M=3           M=9
# 0 -0.00232  1.060444   0.600007  5.440597e-01
# 1      NaN -2.125528   6.993484  3.315843e+02
# 2      NaN       NaN -25.782031 -7.361426e+03
# 3      NaN       NaN  17.900591  6.510218e+04
# 4      NaN       NaN        NaN -3.017533e+05
# 5      NaN       NaN        NaN  8.106851e+05
# 6      NaN       NaN        NaN -1.306766e+06
# 7      NaN       NaN        NaN  1.245651e+06
# 8      NaN       NaN        NaN -6.469265e+05
# 9      NaN       NaN        NaN  1.410361e+05

# %%
run 03-maximum_likelihood.py

# %%
run 03-ml_gauss.py

# %%
run 03-estimator_bias.py

# %%
run 04-perceptron.py

# %%
run 05-logistic_vs_perceptron.py

# %%
run 05-roc_curve.py
# Out:
# E:\git-repos\ml4se\scripts\05-roc_curve.py:83: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   training_set.ix[index, 'probability'] = p

# %%
run 06-k_means.py
# Out:
# ...
# Number of clusters: K=2
# Initial centers:
# [[11, 254, 46], [77, 231, 3]]
# ...
# E:\git-repos\ml4se\scripts\06-k_means.py:54: RuntimeWarning: invalid value encountered in true_divide
#   center_new[i] = center_new[i] / num_points[i]
# [[nan, nan, nan], [160.31939751000445, 144.59393063583815, 126.30347376611827]]
# Distortion: J=8595723977
# [[nan, nan, nan], [160.31939751000445, 144.59393063583815, 126.30347376611827]]
# Distortion: J=3267954983
# [[nan, nan, nan], [160.31939751000445, 144.59393063583815, 126.30347376611827]]
# Distortion: J=3267954983
# (160, 144, 126)
#
# ...
# Number of clusters: K=3
# Initial centers:
# [[83, 190, 82], [4, 19, 237], [162, 231, 133]]
# ...
# [[102.44021275940321, 95.22006017230225, 56.58396911292061], [nan, nan, nan], [228.61547502211238, 202.8539372129936, 208.5708504476997]]
# Distortion: J=2884784818
# [[109.61118784530387, 95.69906531446303, 61.28373571482631], [nan, nan, nan], [232.5418373396572, 214.23366928964106, 218.90946696130214]]
# ...

# %%
run 07-prep_data.py

# %%
run 07-mix_em.py
# Out:
# iter_num 0
# iter_num 1
# iter_num 2
# iter_num 3
# iter_num 4
# iter_num 5
# iter_num 6
# iter_num 7
# iter_num 8
# iter_num 9
# E:\git-repos\ml4se\scripts\07-mix_em.py:36: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   subplot.imshow(df.ix[j].reshape(28,28), cmap=plt.cm.gray_r)
# E:\git-repos\ml4se\scripts\07-mix_em.py:36: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   subplot.imshow(df.ix[j].reshape(28,28), cmap=plt.cm.gray_r)

# %%
run 08-bayes_normal.py

# %%
run 08-bayes_regression.py
# Out:
# E:\git-repos\ml4se\scripts\08-bayes_regression.py:60: RuntimeWarning: invalid value encountered in sqrt
#   deviation = np.sqrt(1.0/beta + np.dot(np.dot(phi_x0.T, s), phi_x0))
